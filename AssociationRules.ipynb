# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('Test2.xlsx')

# %%
df
df_ls = df.values.tolist()

# %%
#Removing duplicate values
nlst = []
type(nlst)
flst = []

s = {''}
for i in range(0,4999):
    for i in df_ls[i]:
            s.add(i)
    nlst = list(s)
    flst.append(nlst)
    s.clear()

# %%
'''s = {''}
tlst = []
nlst1 = []

for i in range(0,19):
    for i in flst[i]:
        if i!=np.nan and i!=None:
            s.add(i)
    nlst1 = list(s)
    tlst.append(nlst)
    s.clear()
    '''

# %%
from pandas import DataFrame
df1 = DataFrame(flst)

# %%
df1
# Out:
#                0              1               2               3    \
# 0                     AMOXICILLIN             NaN   ACETAMINOPHEN
# 1      AMOXICILLIN            HCL             NaN     CLINDAMYCIN
# 2              NaN    AMOXICILLIN            None            None
# 3         FUMARATE   ESCITALOPRAM       LABETALOL      LISINOPRIL
# 4              HCL      POTASSIUM             NaN      PENICILLIN
# ...            ...            ...             ...             ...
# 4994           HCL            NaN      GABAPENTIN     HYDRALAZINE
# 4995           HCL   ESCITALOPRAM        LEVODOPA             NaN
# 4996           HCL            NaN   CHLORHEXIDINE       GLUCONATE
# 4997           NaN     MOMETASONE      CICLOPIROX   METRONIDAZOLE
# 4998           NaN   ESCITALOPRAM     BENZTROPINE     ZIPRASIDONE
#
#                4               5            6               7    \
# 0      HYDROCODONE      CEPHALEXIN         None            None
# ...

# %%
df1.to_csv('Test2.csv')
